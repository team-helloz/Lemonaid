# %%
import pandas as pd

# %%
# 의료기관 별 진료과목 데이터 읽기
hostpital_medical_subject = pd.read_csv("./data/hospitol_medical_subject.csv", encoding='cp949')

# %%
h_m_s = hostpital_medical_subject.drop(hostpital_medical_subject.columns[4:6], axis=1)

# %%
h_m_s
# Out:
#                                                   암호화요양기호           요양기관명  \
# 0       JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...  가톨릭대학교 여의도성모병원
# 1       JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...      서울특별시 동부병원
# 2       JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...         경희대학교병원
# 3       JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...     인제대학교 서울백병원
# 4       JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...            경찰병원
# ...                                                   ...             ...
# 355872  JDQ4MTYyMiM4MSMkMSMkMCMkMTMkNDgxMzUxIzMxIyQxIy...         가온자리한의원
# 355873  JDQ4MTYyMiM4MSMkMSMkMCMkMTMkNDgxMzUxIzMxIyQyIy...       성서중앙성신한의원
# 355874  JDQ4MTYyMiM4MSMkMSMkMCMkMTMkNDgxMzUxIzQxIyQxIy...           동의한의원
# 355875  JDQ4MTYyMiM4MSMkMSMkMCMkMTMkNDgxMzUxIzMxIyQxIy...          따뜻한한의원
# 355876  JDQ4MTYyMiM4MSMkMSMkMCMkMTMkNDgxMzUxIzQxIyQyIy...         맑은소리한의원
#
#         진료과목코드 진료과목코드명
# 0            1      내과
# 1            1      내과
# ...

# %%
h_m_s.to_csv("./output/hospitol_medical_subject.csv", sep=',', encoding="utf-8-sig")

# %%
# 진료과목 데이터 생성
# 주어진 데이터를 중복값없이 처리 후 새로운 데이터 프레임으로 생성
# 해당 데이터 프레임 csv로 저장

# %%
h_m_s = h_m_s.drop(h_m_s.columns[[0, 1]], axis=1)

# %%
h_m_s
# Out:
#         진료과목코드 진료과목코드명
# 0            1      내과
# 1            1      내과
# 2            1      내과
# 3            1      내과
# 4            1      내과
# ...        ...     ...
# 355872      88    한방응급
# 355873      88    한방응급
# 355874      88    한방응급
# 355875      88    한방응급
# 355876      88    한방응급
#
# [355877 rows x 2 columns]

# %%
h_m_s.drop_duplicates()
# Out:
#         진료과목코드       진료과목코드명
# 0            1            내과
# 23050        2           신경과
# 28305        3       정신건강의학과
# 31758        4            외과
# 40983        5          정형외과
# 52608        6          신경외과
# 59540        7          흉부외과
# 60644        8          성형외과
# 65480        9       마취통증의학과
# 72480       10          산부인과
# 76643       11        소아청소년과
# 91990       12            안과
# 96295       13         이비인후과
# 108361      14           피부과
# 124688      15         비뇨의학과
# 124771      15          비뇨기과
# 132835      16         영상의학과
# 136547      17       방사선종양학과
# 136854      18           병리과
# 137856      19       진단검사의학과
# 139342      20           결핵과
# 139652      21         재활의학과
# 146065      22          핵의학과
# 146295      23         가정의학과
# 155632      24         응급의학과
# 156427      25       직업환경의학과
# 156839      26         예방의학과
# 157211      49            치과
# 168382      50       구강악안면외과
# 176148      51         치과보철과
# 184468      52         치과교정과
# ...

# %%
h_m_s.drop_duplicates().to_csv("./output/medical_subject.csv", sep=',', encoding="utf-8-sig")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-979886232676> in <module>
# ----> 1 h_m_s.drop_duplicates(["진료과목코드"],ignore_index = True).to_csv("./output/medical_subject.csv", sep=',', encoding="utf-8-sig")
#
# TypeError: drop_duplicates() got an unexpected keyword argument 'ignore_index'
