# %%
import pandas as pd

# %%
data1 = pd.read_csv("./data2/medicine1.csv")

# %%
data2 = pd.read_csv("./output/medicine_craw.csv")

# %%
data3 = pd.read_csv("./data2/medicine3.csv")
data4 = pd.read_csv("./data2/medicine4.csv")

# %%
data1 = data1.drop(1)

# %%
data1
# Out:
#           품목일련번호                      품목명  \
# 2      200808876  가스디알정50밀리그램(디메크로틴산마그네슘)
# 3      200808877       페라트라정2.5밀리그램(레트로졸)
# 4      200808948         졸뎀속붕정(졸피뎀타르타르산염)
# 5      200809076    가스프렌정(모사프리드시트르산염이수화물)
# 6      200809276         디텐션정80밀리그램(발사르탄)
# ...          ...                      ...
# 9997   201800785        텔미온정40밀리그램(텔미사르탄)
# 9998   201405006                     알비트정
# 9999   201903480     안포디필서방정(사르포그렐레이트염산염)
# 10000  201908167        파모티린정20밀리그램(파모티딘)
# 10001  201906521                  굿트라셋세미정
#
#                                                원료약품 및 분량  \
# 2      유효성분 : 디메크로틴산마그네슘|총량 : 1정 (161.0mg) 중  |  성분명 ...
# 3      유효성분 : 레트로졸|총량 : 이 약 1정(약 103mg) 중  |  성분명 : 레...
# 4      유효성분 : 졸피뎀타르타르산염|총량 : 1정 (250.0mg) 중  |  성분명 :...
# 5      유효성분 : 모사프리드시트르산염이수화물|총량 : 이 약 1정(135밀리그램) 중  ...
# 6      유효성분 : 발사르탄|총량 : 1정 (166mg) 중  |  성분명 : 발사르탄  ...
# ...                                                  ...
# ...

# %%
data2
# Out:
#          품목일련번호                 품목명  \
# 0     199401316       세리콘정(아세트아미노펜)
# 1     199801844  세리콘정300mg(아세트아미노펜)
# 2     199801877               아나리바정
# 3     199801849      알지렉스정(세티리진염산염)
# 4     200201701        암시논정(트리암시놀론)
# ...         ...                 ...
# 4995  200606260       졸피아트정(주석산졸피뎀)
# 4996  200608031         아마반정4mg/1mg
# 4997  200608030         아마반정4mg/2mg
# 4998  200608029         아마반정4mg/4mg
# 4999  200701333        메토나정(메토카르바몰)
#
#                                               원료약품 및 분량  \
# 0     유효성분 : 아세트아미노펜|총량 : 1정(600 밀리그램) 중-  |  성분명 : ...
# 1     유효성분 : 아세트아미노펜|총량 : 1정 중 450밀리그램  |  성분명 : 아세트...
# 2     유효성분 : DL-메티오닌,아세트아미노펜|총량 : 1정(633mg) 중  |  성분...
# 3     유효성분 : 세티리진염산염|총량 : 1정(258 밀리그램) 중-  |  성분명 : ...
# 4     유효성분 : 트리암시놀론|총량 : 1정 중 140밀리그램  |  성분명 : 트리암시...
# ...                                                 ...
# 4995  유효성분 : 주석산졸피뎀|총량 : 1정  |  성분명 : 주석산졸피뎀  |  분량 ...
# 4996  유효성분 : 글리메피리드,말레인산로시글리타존|총량 : 이 약 1정(206.0mg) ...
# ...

# %%
data3
# Out:
#          품목일련번호                  품목명  \
# 0     200700565        다모케어정(피나스테리드)
# 1     200701910  디베린엠알정30밀리그람(글리클라짓)
# 2     200611114       레코푸정(레보드로프로피진)
# 3     200604149         코닉스정(주석산졸피뎀)
# 4     200612743    글리메정4밀리그램(글리메피리드)
# ...         ...                  ...
# 4995  201603317     탐루신디서방정(탐스로신염산염)
# 4996  201604529   뉴로닌캡슐100밀리그램(가바펜틴)
# 4997  201602639      르세르정(레보세티리진염산염)
# 4998  201600378     아젤스테인정(아젤라스틴염산염)
# 4999  201600436         심바코틴정(심바스타틴)
#
#                                               원료약품 및 분량  \
# 0     유효성분 : 피나스테리드|총량 : 1정(150 밀리그램) 중-  |  성분명 : 피...
# 1     유효성분 : 글리클라짓|총량 : 1정(169mg) 중  |  성분명 : 글리클라짓 ...
# 2     유효성분 : 레보드로프로피진|총량 : 1정 (250밀리그램 중)  |  성분명 : ...
# 3     유효성분 : 주석산졸피뎀|총량 : 1정(124밀리그람)중  |  성분명 : 주석산졸...
# 4     유효성분 : 글리메피리드|총량 : 1정 (344.6mg) 중  |  성분명 : 글리...
# ...                                                 ...
# 4995  유효성분 : 탐스로신염산염|총량 : 1정 (231.945mg) 중  |  성분명 :...
# 4996  유효성분 : 가바펜틴|총량 : 1캡슐(178mg) 중  |  성분명 : 가바펜틴  ...
# ...

# %%
data4
# Out:
#          품목일련번호                         품목명  \
# 0     201903848       크레로우정20밀리그램(로수바스타틴칼슘)
# 1     201903849       크레로우정10밀리그램(로수바스타틴칼슘)
# 2     201906900          크로원정10mg(로수바스타틴칼슘)
# 3     201906901           크로원정5mg(로수바스타틴칼슘)
# 4     201907911  듀오박탐정500밀리그램(아목시실린·설박탐피복실)
# ...         ...                         ...
# 4311  201903261        몬카츄정5밀리그램(몬테루카스트나트륨)
# 4312  202106679       폴세틴캡슐20밀리그램(플루옥세틴염산염)
# 4313  202102262                  덴티텐캡슐(청위산)
# 4314  202003115                        아스본정
# 4315  200900041             덱시엔연질캡슐(덱시부프로펜)
#
#                                               원료약품 및 분량  \
# 0     유효성분 : 로수바스타틴칼슘|총량 : 1정(308.84 밀리그램) 중-  |  성분...
# 1     유효성분 : 로수바스타틴칼슘|총량 : 1정(154.42 밀리그램) 중-  |  성분...
# 2     유효성분 : 로수바스타틴칼슘|총량 : 1정(154.5 밀리그램) 중-  |  성분명...
# 3     유효성분 : 로수바스타틴칼슘|총량 : 1정(154.5 밀리그램) 중-  |  성분명...
# 4     유효성분 : 설박탐피복실,아목시실린수화물|총량 : 1정(810 밀리그램) 중-  |...
# ...                                                 ...
# ...

# %%
data = pd.concat([data, data4])

# %%
data
# Out:
#           품목일련번호                   품목명  \
# 0      199401316         세리콘정(아세트아미노펜)
# 1      199801844    세리콘정300mg(아세트아미노펜)
# 2      199801877                 아나리바정
# 3      199801849        알지렉스정(세티리진염산염)
# 4      200201701          암시논정(트리암시놀론)
# ...          ...                   ...
# 9997   201800785     텔미온정40밀리그램(텔미사르탄)
# 9998   201405006                  알비트정
# 9999   201903480  안포디필서방정(사르포그렐레이트염산염)
# 10000  201908167     파모티린정20밀리그램(파모티딘)
# 10001  201906521               굿트라셋세미정
#
#                                                원료약품 및 분량  \
# 0      유효성분 : 아세트아미노펜|총량 : 1정(600 밀리그램) 중-  |  성분명 : ...
# 1      유효성분 : 아세트아미노펜|총량 : 1정 중 450밀리그램  |  성분명 : 아세트...
# 2      유효성분 : DL-메티오닌,아세트아미노펜|총량 : 1정(633mg) 중  |  성분...
# 3      유효성분 : 세티리진염산염|총량 : 1정(258 밀리그램) 중-  |  성분명 : ...
# 4      유효성분 : 트리암시놀론|총량 : 1정 중 140밀리그램  |  성분명 : 트리암시...
# ...                                                  ...
# 9997   유효성분 : 텔미사르탄|총량 : 1정(240mg) 중  |  성분명 : 텔미사르탄 ...
# ...

# %%
cnt = 0
for column in data['품목일련번호']:
    cnt += 1
print(cnt)
# Out:
# 24318

# %%
data.to_csv("./output/medicine_craw_total.csv", sep=',', na_rep=-1, encoding="utf-8-sig")

# %%
medicine_shape = pd.read_csv("./data/medicine_shape.csv")

# %%
medicine_final = pd.merge(medicine_shape, data, left_on="품목일련번호", right_on="품목일련번호", how="left")

# %%
cnt = 0
for column in data:
    print(column, cnt)
    cnt += 1
# Out:
# 품목일련번호 0
# 품목명 1
# 원료약품 및 분량 2
# 효능효과 3
# 용법용량 4
# 사용상의주의사항 5

# %%
medicine_final.head()
# Out:
#       품목일련번호                    품목명_x    업소일련번호      업소명                  성상  \
# 0  200808876  가스디알정50밀리그램(디메크로틴산마그네슘)  19540006  일동제약(주)          녹색의원형필름코팅정
# 1  200808877       페라트라정2.5밀리그램(레트로졸)  19560004  (주)유한양행       어두운황색의원형필름코팅정
# 2  200808948         졸뎀속붕정(졸피뎀타르타르산염)  20080422  보령제약(주)         흰색의원형구강붕해정제
# 3  200809076    가스프렌정(모사프리드시트르산염이수화물)  19760002  경동제약(주)  분할선을가진흰색의장방형필름코팅정제
# 4  200809276         디텐션정80밀리그램(발사르탄)  19700003  일성신약(주)         주황색의원형필름코팅정
#
#    표시앞    표시뒤 의약품제형 색상앞 색상뒤  ...  제형코드명 표기내용앞 표기내용뒤 표기코드앞 표기코드뒤  \
# 0  IDG      -    원형  연두   -  ...    당의정     -     -     -     -
# 1   YH     LT    원형  노랑   -  ...  필름코팅정     -     -     -     -
# 2    -      -    원형  하양   -  ...     정제     -     -     -     -
# 3   KD    분할선   장방형  하양   -  ...  필름코팅정     -     -     -     -
# 4  ISP  D분할선T    원형  분홍   -  ...  필름코팅정     -     -     -     -
#
#                      품목명_y                                          원료약품 및 분량  \
# ...

# %%
medicine_final[medicine_final['효능효과'].isna()]
# Out:
#           품목일련번호                       품목명_x    업소일련번호         업소명  \
# 101    200902743                       오메콜캡슐  19590004     청계제약(주)
# 104    200902801                       카페그린정  19590004     청계제약(주)
# 105    200902805                      트리답티브정  20160587   한국엠에스디(주)
# 133    200903698                     맥스콜연질캡슐  19890010     한솔신약(주)
# 146    200903912                       디펜에이정  20090254  (주)제이앤피코리아
# ...          ...                         ...       ...         ...
# 10972  200100776                      덴티넥스캡슐  19570006     동화약품(주)
# 10978  200710213  라실레즈정300밀리그램(알리스키렌헤미푸마르산염)  20161462   한국노바티스(주)
# 10988  200710212  라실레즈정150밀리그램(알리스키렌헤미푸마르산염)  20161462   한국노바티스(주)
# 12330  201310005           마이큐탄연질캡슐(이소트레티노인)  19550012    (주)마더스제약
# 13333  201309933      글루세라서방정500mg(메트포르민염산염)  19570010    삼천당제약(주)
#
#                                                       성상  \
# 101                           백색-미황색의가루가든상부청색|하부흰색의경질캡슐제
# ...

# %%
medicine_final.to_csv("./output/medicine_final2.csv", sep=',', na_rep=-1, encoding="utf-8-sig")

# %%
cnt = 0
for column in medicine_final:
    print(column, cnt)
    cnt += 1
# Out:
# 품목일련번호 0
# 품목명_x 1
# 업소일련번호 2
# 업소명 3
# 성상 4
# 표시앞 5
# 표시뒤 6
# 의약품제형 7
# 색상앞 8
# 색상뒤 9
# 분할선앞 10
# 분할선뒤 11
# 크기장축 12
# 크기단축 13
# 크기두께 14
# 분류번호 15
# 분류명 16
# 전문일반구분 17
# 제형코드명 18
# 표기내용앞 19
# 표기내용뒤 20
# 표기코드앞 21
# 표기코드뒤 22
# 품목명_y 23
# 원료약품 및 분량 24
# 효능효과 25
# 용법용량 26
# 사용상의주의사항 27

# %%
medicine_final = medicine_final.drop(medicine_final.columns[[5, 16, 20, 24, 25, 28, 29]], axis=1)

# %%
medicine_shape
# Out:
#           품목일련번호                      품목명    업소일련번호         업소명  \
# 0      200808876  가스디알정50밀리그램(디메크로틴산마그네슘)  19540006     일동제약(주)
# 1      200808877       페라트라정2.5밀리그램(레트로졸)  19560004     (주)유한양행
# 2      200808948         졸뎀속붕정(졸피뎀타르타르산염)  20080422     보령제약(주)
# 3      200809076    가스프렌정(모사프리드시트르산염이수화물)  19760002     경동제약(주)
# 4      200809276         디텐션정80밀리그램(발사르탄)  19700003     일성신약(주)
# ...          ...                      ...       ...         ...
# 24311  201903261     몬카츄정5밀리그램(몬테루카스트나트륨)  19700003     일성신약(주)
# 24312  202106679    폴세틴캡슐20밀리그램(플루옥세틴염산염)  19840009    (주)알피바이오
# 24313  202102262               덴티텐캡슐(청위산)  19840009    (주)알피바이오
# 24314  202003115                     아스본정  19560011     삼진제약(주)
# 24315  200900041          덱시엔연질캡슐(덱시부프로펜)  19570024  에스케이케미칼(주)
#
#                                    성상  \
# 0                          녹색의원형필름코팅정
# 1                       어두운황색의원형필름코팅정
# 2                         흰색의원형구강붕해정제
# 3                  분할선을가진흰색의장방형필름코팅정제
# ...

# %%
print(medicine_shape.dtypes)
# Out:
# 품목일련번호              int64
# 품목명                object
# 업소일련번호              int64
# 업소명                object
# 성상                 object
# 큰제품이미지             object
# 표시앞                object
# 표시뒤                object
# 의약품제형              object
# 색상앞                object
# 색상뒤                object
# 분할선앞               object
# 분할선뒤               object
# 크기장축               object
# 크기단축               object
# 크기두께               object
# 이미지생성일자(약학정보원)      int64
# 분류번호               object
# 분류명                object
# 전문일반구분             object
# 품목허가일자              int64
# 제형코드명              object
# 표기내용앞              object
# 표기내용뒤              object
# 표기이미지앞             object
# 표기이미지뒤             object
# 표기코드앞              object
# 표기코드뒤              object
# 변경일자               object
# Unnamed: 29       float64
# dtype: object

# %%
data1["품목일련번호"] = data1["품목일련번호"].astype(int)

# %%
medicine_test = pd.merge(medicine_shape, data1, left_on="품목일련번호", right_on="품목일련번호", how="left")

# %%
medicine_test[medicine_test['사용상의주의사항'].isna()]
# Out:
#           품목일련번호                    품목명_x    업소일련번호           업소명  \
# 0      200808876  가스디알정50밀리그램(디메크로틴산마그네슘)  19540006       일동제약(주)
# 1      200808877       페라트라정2.5밀리그램(레트로졸)  19560004       (주)유한양행
# 2      200808948         졸뎀속붕정(졸피뎀타르타르산염)  20080422       보령제약(주)
# 3      200809076    가스프렌정(모사프리드시트르산염이수화물)  19760002       경동제약(주)
# 4      200809276         디텐션정80밀리그램(발사르탄)  19700003       일성신약(주)
# ...          ...                      ...       ...           ...
# 23432  202007078                  멀티브큐골드정  19600011       미래제약(주)
# 23433  202007080                   미네큐비타정  19600011       미래제약(주)
# 23863  202101239                    아메론캡슐  19720008  시믹씨엠오코리아주식회사
# 23917  202104243                  제트유플러스정  19570013       일양약품(주)
# 24121  202107556               아로나민실버액티브정  19540006       일동제약(주)
#
#                            성상  \
# 0                  녹색의원형필름코팅정
# 1               어두운황색의원형필름코팅정
# 2                 흰색의원형구강붕해정제
# 3          분할선을가진흰색의장방형필름코팅정제
# ...
